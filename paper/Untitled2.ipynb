# %%
import os

os.chdir(r'D:\R for sta\dta')

# %%
import pandas as pd

# %%
school = pd.read_stata('school.dta')

school.head()
# Out:
#    obs  pub12  pub34  pub5  private  years  school     loginc  logptax  vote  \
# 0    1      0      1     0        0     10       1   9.770001   7.0475     1
# 1    2      0      1     0        0      8       0  10.021000   7.0475     0
# 2    3      1      0     0        0      4       0  10.021000   7.0475     0
# 3    4      0      1     0        0     13       0   9.433500   6.3969     0
# 4    5      0      1     0        0      3       1  10.021000   7.2792     1
#
#     logeduc
# 0  7.206195
# 1  7.609900
# 2  8.278470
# 3  6.821488
# 4  7.686149

# %%
school.to_csv('school.csv',index=False)

# %%
school = school.iloc[:, 1:]

# %%
school
# Out:
#     pub12  pub34  pub5  private  years  school     loginc  logptax  vote  \
# 0       0      1     0        0     10       1   9.770001   7.0475     1
# 1       0      1     0        0      8       0  10.021000   7.0475     0
# 2       1      0     0        0      4       0  10.021000   7.0475     0
# 3       0      1     0        0     13       0   9.433500   6.3969     0
# 4       0      1     0        0      3       1  10.021000   7.2792     1
# ..    ...    ...   ...      ...    ...     ...        ...      ...   ...
# 90      1      0     0        0      3       0  10.222000   7.2793     1
# 91      0      1     0        0      3       1  10.021000   7.0475     1
# 92      0      0     1        0      5       0  10.021000   7.0475     1
# 93      0      0     0        0     35       1   8.922700   5.9915     1
# 94      0      1     0        0      3       0  10.463000   7.4955     0
#
#      logeduc
# 0   7.206195
# 1   7.609900
# 2   8.278470
# 3   6.821488
# 4   7.686149
# ...

# %%
school["wow"] = school["private"]*school["vote"]

school
# Out:
#     pub12  pub34  pub5  private  years  school     loginc  logptax  vote  \
# 0       0      1     0        0     10       1   9.770001   7.0475     1
# 1       0      1     0        0      8       0  10.021000   7.0475     0
# 2       1      0     0        0      4       0  10.021000   7.0475     0
# 3       0      1     0        0     13       0   9.433500   6.3969     0
# 4       0      1     0        0      3       1  10.021000   7.2792     1
# ..    ...    ...   ...      ...    ...     ...        ...      ...   ...
# 90      1      0     0        0      3       0  10.222000   7.2793     1
# 91      0      1     0        0      3       1  10.021000   7.0475     1
# 92      0      0     1        0      5       0  10.021000   7.0475     1
# 93      0      0     0        0     35       1   8.922700   5.9915     1
# 94      0      1     0        0      3       0  10.463000   7.4955     0
#
#      logeduc  wow
# 0   7.206195    0
# 1   7.609900    0
# 2   8.278470    0
# ...

# %%
school[school["wow"]==1]
# Out:
#     pub12  pub34  pub5  private  years  school     loginc  logptax  vote  \
# 19      1      0     0        1      4       0  10.222000   6.7452     1
# 29      1      0     0        1      2       0  10.222000   7.0475     1
# 33      0      0     0        1      4       0  10.463000   7.0475     1
# 68      0      1     0        1      3       0  10.021000   7.0475     1
# 85      1      0     0        1      3       0   9.770001   7.0475     1
#
#      logeduc  wow
# 19  7.579166    1
# 29  8.470457    1
# 33  7.905035    1
# 68  6.512567    1
# 85  9.024509    1

# %%
school.to_csv('school.csv',index=False)

# %%
school.describe()
# Out:
#            pub12      pub34       pub5    private      years     school  \
# count  95.000000  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    0.484211   0.315789   0.042105   0.105263   8.515789   0.115789
# std     0.502402   0.467295   0.201895   0.308520   9.515791   0.321670
# min     0.000000   0.000000   0.000000   0.000000   1.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   3.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   5.000000   0.000000
# 75%     1.000000   1.000000   0.000000   0.000000  10.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000  49.000000   1.000000
#
#           loginc    logptax       vote    logeduc        wow
# count  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    9.971017   6.939491   0.621053   7.543318   0.052632
# std     0.411885   0.316920   0.487699   0.491541   0.224481
# min     8.294000   5.991500   0.000000   6.512567   0.000000
# ...

# %%
# %pwd
# Out:
# 'D:\\R for sta\\dta'

# %%
os.chdir()
