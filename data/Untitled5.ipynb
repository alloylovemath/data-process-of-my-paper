# %%
import pandas as pd
import numpy as np
import os

os.chdir(r'D:\paper\rowdata\1')

data = pd.read_stata('row_33333.dta')

data[data['Vio_wide'] == 1].to_csv('999999.csv', index=False)

# %%
test_1 = test_1.dropna()

code_ls = []
for i in test_1["Code"]:
    if i not in code_ls:
        code_ls.append(i)
        
zcze_ls = []
zcfz_ls = []
roa_ls = []
tobin_ls = []
HHI_ls = []
hbl_ls = []
hsl_ls = []
first_ls = []
twoten_ls = []
jgtzz_ls = []
lzhy_ls = []
glccg_ls = []
dshgmlog_ls = []
ddzb_ls = []
fxslg_ls = []
sjjg_ls = []
for code in code_ls:
    zcze_ls = zcze_ls + list(test_1[test_1["Code"]==code]["Zczelog"].shift(1))
    zcfz_ls = zcfz_ls + list(test_1[test_1["Code"]==code]["Zcfz"].shift(1))
    roa_ls = roa_ls + list(test_1[test_1["Code"]==code]["Roa"].shift(1))
    tobin_ls = tobin_ls + list(test_1[test_1["Code"]==code]["TobinQ"].shift(1))
    HHI_ls = HHI_ls + list(test_1[test_1["Code"]==code]["HHI"].shift(1))
    hbl_ls = hbl_ls + list(test_1[test_1["Code"]==code]["Hbl"].shift(1))
    hsl_ls = hsl_ls + list(test_1[test_1["Code"]==code]["Hsl"].shift(1))
    first_ls = first_ls + list(test_1[test_1["Code"]==code]["First"].shift(1))
    twoten_ls = twoten_ls + list(test_1[test_1["Code"]==code]["Two_ten"].shift(1))
    jgtzz_ls = jgtzz_ls + list(test_1[test_1["Code"]==code]["Jgtzz"].shift(1))
    lzhy_ls = lzhy_ls + list(test_1[test_1["Code"]==code]["Lzhy"].shift(1))
    glccg_ls = glccg_ls + list(test_1[test_1["Code"]==code]["Glccg"].shift(1))
    dshgmlog_ls = dshgmlog_ls + list(test_1[test_1["Code"]==code]["Dshgmlog"].shift(1))
    ddzb_ls = ddzb_ls + list(test_1[test_1["Code"]==code]["Ddzb"].shift(1))
    fxslg_ls = fxslg_ls + list(test_1[test_1["Code"]==code]["Fxslg"].shift(1))
    sjjg_ls = sjjg_ls + list(test_1[test_1["Code"]==code]["Sjjg"].shift(1))

df = test_1

df["Zczelog"] = zcze_ls
df["Zcfz"] = zcfz_ls
df["Roa"] = roa_ls
df["TobinQ"] = tobin_ls
df["HHI"] = HHI_ls
df["Hbl"] = hbl_ls
df["Hsl"] = hsl_ls
df["First"] = first_ls
df["Two_ten"] = twoten_ls
df["Jgtzz"] = jgtzz_ls
df["Lzhy"] = lzhy_ls
df["Glccg"] = glccg_ls
df["Dshgmlog"] = dshgmlog_ls
df["Ddzb"] = ddzb_ls
df["Fxslg"] = fxslg_ls
df["Sjjg"] = sjjg_ls

test_1 = df

test_1 = test_1[test_1["Time"]>=2014]

code_ls = []
for i in test_1["Code"]:
    if i not in code_ls:
        code_ls.append(i)
        
tc_code = []
for i in range(len(test_1["Code"])):
    if test_1.iloc[i,:][10] != test_1.iloc[i,:][11]:
        tc_code.append(test_1.iloc[i,:].name)

test_1 = test_1.drop(tc_code)


test_1 = test_1[test_1["Zcfz"]<1]


os.chdir(r'D:\paper\rowdata\ST')
ST = pd.read_csv("ST.csv", dtype={"Symbol": str})
ST = ST[ST["FirstSTDate"].notnull()]["Symbol"].values


ST_ls = []
for item in test_1["Code"]:
    if item in ST:
        ST_ls.append(1)
    else:
        ST_ls.append(0)

test_1["ST"] = ST_ls
test_1 = test_1[test_1["ST"]!=1]
test_1 = test_1.drop(["ST"],axis=1)

test_1["Jlr_t"] = [1 if i > 0 else 0 for i in test_1["Jlr"]]

test_1["Rzmr"] = test_1["Rzmr"] / test_1["Ltsz"]
test_1["Rqmc"] = test_1["Rqmc"] / test_1["Ltsz"]
test_1["Rzye"] = test_1["Rzye"] / test_1["Ltsz"]
test_1["Rqye"] = test_1["Rqye"] / test_1["Ltsz"]

row_data = test_1.copy()

from scipy.stats.mstats import winsorize

row_data["Zczelog"] = winsorize(row_data["Zczelog"], limits=[0.01, 0.01])
row_data["Ltszlog"] = winsorize(row_data["Ltszlog"], limits=[0.01, 0.01])
row_data["Zcfz"] = winsorize(row_data["Zcfz"], limits=[0.01, 0.01])
row_data["Yszz"] = winsorize(row_data["Yszz"], limits=[0.01, 0.01])
row_data["Roa"] = winsorize(row_data["Roa"], limits=[0.01, 0.01])
row_data["TobinQ"] = winsorize(row_data["TobinQ"], limits=[0.01, 0.01])
row_data["Hbl"] = winsorize(row_data["Hbl"], limits=[0.01, 0.01])
row_data["Hsl"] = winsorize(row_data["Hsl"], limits=[0.01, 0.01])
row_data["First"] = winsorize(row_data["First"], limits=[0.01, 0.01])
row_data["Two_ten"] = winsorize(row_data["Two_ten"], limits=[0.01, 0.01])
row_data["Gqzhd"] = winsorize(row_data["Gqzhd"], limits=[0.01, 0.01])
row_data["Jgtzz"] = winsorize(row_data["Jgtzz"], limits=[0.01, 0.01])
row_data["Glccg"] = winsorize(row_data["Glccg"], limits=[0.01, 0.01])
row_data["Dshgmlog"] = winsorize(row_data["Dshgmlog"], limits=[0.01, 0.01])
row_data["Ddzb"] = winsorize(row_data["Ddzb"], limits=[0.01, 0.01])
row_data["Fxslg"] = winsorize(row_data["Fxslg"], limits=[0.01, 0.01])
row_data["Ssnxlog"] = winsorize(row_data["Ssnxlog"], limits=[0.01, 0.01])
row_data["HTobinQ"] = winsorize(row_data["HTobinQ"], limits=[0.01, 0.01])
row_data["HHI"] = winsorize(row_data["HHI"], limits=[0.01, 0.01])
row_data["Yylr"] = winsorize(row_data["Yylr"], limits=[0.01, 0.01])
row_data["Jlr"] = winsorize(row_data["Jlr"], limits=[0.01, 0.01])
row_data["Qtyskzj"] = winsorize(row_data["Qtyskzj"], limits=[0.01, 0.01])
row_data["Zjzy"] = winsorize(row_data["Zjzy"], limits=[0.01, 0.01])
row_data["Zjzy_t"] = winsorize(row_data["Zjzy_t"], limits=[0.01, 0.01])
row_data["Qtyskzj_t"] = winsorize(row_data["Qtyskzj_t"], limits=[0.01, 0.01])

rzmr_q1 = row_data[row_data["Post"]==1]["Rzmr"].quantile(0.01, interpolation='lower')
rzmr_q2 = row_data[row_data["Post"]==1]["Rzmr"].quantile(0.99, interpolation='higher')
rzye_q1 = row_data[row_data["Post"]==1]["Rzye"].quantile(0.01, interpolation='lower')
rzye_q2 = row_data[row_data["Post"]==1]["Rzye"].quantile(0.99, interpolation='higher')
rqmc_q1 = row_data[row_data["Post"]==1]["Rqmc"].quantile(0.01, interpolation='lower')
rqmc_q2 = row_data[row_data["Post"]==1]["Rqmc"].quantile(0.99, interpolation='higher')
rqye_q1 = row_data[row_data["Post"]==1]["Rqye"].quantile(0.01, interpolation='lower')
rqye_q2 = row_data[row_data["Post"]==1]["Rqye"].quantile(0.99, interpolation='higher')

rzmr = []
for i in range(len(row_data["Code"])):
    qq = row_data.iloc[i, :]
    if qq["Post"] == 0:
        rzmr.append(0)
    else:
        if qq["Rzmr"] <= rzmr_q1:
            rzmr.append(rzmr_q1)
        elif qq["Rzmr"] >= rzmr_q2:
            rzmr.append(rzmr_q2)
        else:
            rzmr.append(qq["Rzmr"])
row_data["Rzmr"] = rzmr

rzye = []
for i in range(len(row_data["Code"])):
    qq = row_data.iloc[i, :]
    if qq["Post"] == 0:
        rzye.append(0)
    else:
        if qq["Rzye"] <= rzye_q1:
            rzye.append(rzye_q1)
        elif qq["Rzye"] >= rzye_q2:
            rzye.append(rzye_q2)
        else:
            rzye.append(qq["Rzye"])
row_data["Rzye"] = rzye

rqmc = []
for i in range(len(row_data["Code"])):
    qq = row_data.iloc[i, :]
    if qq["Post"] == 0:
        rqmc.append(0)
    else:
        if qq["Rqmc"] <= rqmc_q1:
            rqmc.append(rqmc_q1)
        elif qq["Rqmc"] >= rqmc_q2:
            rqmc.append(rqmc_q2)
        else:
            rqmc.append(qq["Rqmc"])
row_data["Rqmc"] = rqmc

rqye = []
for i in range(len(row_data["Code"])):
    qq = row_data.iloc[i, :]
    if qq["Post"] == 0:
        rqye.append(0)
    else:
        if qq["Rqye"] <= rqye_q1:
            rqye.append(rqye_q1)
        elif qq["Rqye"] >= rqye_q2:
            rqye.append(rqye_q2)
        else:
            rqye.append(qq["Rqye"])
row_data["Rqye"] = rqye

os.chdir(r'D:\paper\rowdata\1')
row_data["Industry"] = row_data["Industry"].astype('category')
row_data["Code"] = row_data["Code"].astype('category')
row_data.to_stata("row_777777_11.dta", write_index=False)
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Zczelog"] = zcze_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Zcfz"] = zcfz_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Roa"] = roa_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TobinQ"] = tobin_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HHI"] = HHI_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Hbl"] = hbl_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Hsl"] = hsl_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["First"] = first_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Two_ten"] = twoten_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Jgtzz"] = jgtzz_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Lzhy"] = lzhy_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Glccg"] = glccg_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dshgmlog"] = dshgmlog_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ddzb"] = ddzb_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fxslg"] = fxslg_ls
# C:\Users\S\AppData\Local\Temp\ipykernel_13868\529035674.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sjjg"] = sjjg_ls

# %%
ddd = pd.read_stata('row_777777_11.dta')
ddd
# Out:
#         Code  Time  Vio  NumVio_wide          Zcze    Zczelog       Qtyskzj  \
# 0     000002  2014    0            0  1.746387e+11  25.644762  7.129091e+09
# 1     000002  2015    0            0  1.945915e+11  25.644762  7.129091e+09
# 2     000002  2016    0            1  2.205133e+11  25.644762  7.129091e+09
# 3     000002  2017    0            0  3.302305e+11  25.644762  7.129091e+09
# 4     000002  2018    0            0  4.563822e+11  25.644762 -2.317848e+09
# ...      ...   ...  ...          ...           ...        ...           ...
# 9842  603998  2017    0            0  1.274708e+09  20.888610 -5.112947e+07
# 9843  603998  2018    0            0  1.537012e+09  20.965983  2.352565e+08
# 9844  603998  2019    0            1  1.793355e+09  21.153106  6.165287e+07
# 9845  603999  2017    0            0  1.809583e+09  21.283823  8.561978e+06
# 9846  603999  2018    0            0  1.944695e+09  21.316362 -3.930393e+05
#
#               Zjzy    Zjzy_t  Qtyskzj_t  ...     Fxslg  Sjjg  Industry  Cqxz  \
# 0     1.600752e+10  0.413210   0.089314  ...  3.761200   1.0         K     1
# 1     1.600752e+10  0.342491   0.067869  ...  3.663562   1.0         K     1
# 2     1.600752e+10  0.301571   0.337892  ...  3.688879   1.0         K     1
# 3     1.600752e+10  0.262605   0.329650  ...  3.295837   1.0         K     1
# 4     1.600752e+10  0.299477  -0.017731  ...  3.761200   1.0         K     1
# ...            ...       ...        ...  ...       ...   ...       ...   ...
# 9842 -2.591887e+07 -0.020333  -0.040111  ...  0.693147   0.0         C     0
# 9843 -1.416112e+08 -0.092134   0.153061  ...  0.000000   0.0         C     0
# 9844  2.837951e+07  0.015825   0.034379  ...  0.000000   0.0         C     0
# 9845  2.504609e+08  0.138408   0.004731  ...  0.693147   0.0         R     1
# 9846  1.183232e+08  0.060844  -0.000202  ...  0.693147   0.0         R     1
#
#        Ssnxlog   HTobinQ       HHI          Yylr           Jlr  Jlr_t
# 0     3.178054  0.845271  0.076325  7.526181e+09  6.899604e+09      1
# 1     3.218876  1.415158  0.077816  7.526181e+09  6.899604e+09      1
# 2     3.258097  0.701672  0.093969  7.526181e+09  6.899604e+09      1
# 3     3.295837  0.521176  0.096350  7.526181e+09  6.899604e+09      1
# 4     3.295837  0.339403  0.101849  7.526181e+09  6.899604e+09      1
# ...        ...       ...       ...           ...           ...    ...
# 9842  1.386294  3.654711  0.028850  7.435314e+07  6.078344e+07      1
# 9843  1.609438  2.933394  0.026890  7.900926e+07  6.949832e+07      1
# 9844  1.791759  4.721329  0.029387  1.039226e+08  9.101487e+07      1
# 9845  1.098612  1.910157  0.093014  8.422745e+07  9.152340e+07      1
# 9846  1.386294  1.105446  0.076465  6.350450e+07  6.100107e+07      1
#
# [9847 rows x 46 columns]

# %%
pd.read_stata('row_9999_11.dta')
# Out:
#          Code  Time  Vio_wide  NumVio_wide          Zcze    Zczelog  \
# 0      000002  2014         0            0  1.746387e+11  25.678537
# 1      000002  2015         0            0  1.945915e+11  25.678537
# 2      000002  2016         1            1  2.205133e+11  25.678537
# 3      000002  2017         0            0  3.302305e+11  25.678537
# 4      000002  2018         0            0  4.563822e+11  25.678537
# ...       ...   ...       ...          ...           ...        ...
# 10678  603998  2018         0            0  1.537012e+09  21.153106
# 10679  603998  2019         1            1  1.793355e+09  21.307354
# 10680  603999  2016         0            0  1.751648e+09  21.283823
# 10681  603999  2017         0            0  1.809583e+09  21.316362
# 10682  603999  2018         0            0  1.944695e+09  21.388371
#
#             Qtyskzj          Zjzy    Zjzy_t  Qtyskzj_t  ...  Sjjg  Industry  \
# 0      6.858825e+09  1.552746e+10  0.413210   0.089314  ...   1.0         K
# 1      6.858825e+09  1.552746e+10  0.342491   0.067869  ...   1.0         K
# 2      6.858825e+09  1.552746e+10  0.301571   0.337892  ...   1.0         K
# 3      6.858825e+09  1.552746e+10  0.262605   0.329650  ...   1.0         K
# 4     -2.214575e+09  1.552746e+10  0.299477  -0.017731  ...   1.0         K
# ...             ...           ...       ...        ...  ...   ...       ...
# 10678  2.352565e+08 -1.416112e+08 -0.092134   0.153061  ...   0.0         C
# 10679  6.165287e+07  2.837951e+07  0.015825   0.034379  ...   0.0         C
# 10680  7.117054e+06  2.446859e+08  0.139689   0.004063  ...   0.0         R
# 10681  8.561978e+06  2.504609e+08  0.138408   0.004731  ...   0.0         R
# 10682 -3.930393e+05  1.183232e+08  0.060844  -0.000202  ...   0.0         R
#
#        Cqxz   Ssnxlog   HTobinQ       HHI          Yylr           Jlr  \
# 0         1  3.178054  0.845271  0.077816  7.027766e+09  6.567314e+09
# 1         1  3.218876  1.415158  0.093969  7.027766e+09  6.567314e+09
# 2         1  3.258097  0.701672  0.096350  7.027766e+09  6.567314e+09
# 3         1  3.295837  0.521176  0.101849  7.027766e+09  6.567314e+09
# 4         1  3.295837  0.339403  0.093338  7.027766e+09  6.567314e+09
# ...     ...       ...       ...       ...           ...           ...
# 10678     0  1.609438  2.933394  0.029387  7.900926e+07  6.949832e+07
# 10679     0  1.791759  4.721329  0.034775  1.039226e+08  9.101487e+07
# 10680     1  0.693147  2.069841  0.093014  7.678633e+07  8.544740e+07
# 10681     1  1.098612  1.910157  0.076465  8.422745e+07  9.152340e+07
# 10682     1  1.386294  1.105446  0.076048  6.350450e+07  6.100107e+07
#
#                 Jyl  Jlr_t
# 0      2.412700e+11      1
# 1      8.080088e+11      1
# 2      4.027525e+11      1
# 3      2.541093e+11      1
# 4      3.312145e+11      1
# ...             ...    ...
# 10678  5.015992e+09      1
# 10679  3.345872e+10      1
# 10680  8.739284e+10      1
# 10681  1.424403e+10      1
# 10682  6.964034e+09      1
#
# [10683 rows x 47 columns]
